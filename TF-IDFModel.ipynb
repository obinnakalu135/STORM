# %%
import os
import nltk
from nltk.corpus import stopwords
from nltk.util import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
from PyPDF2 import PdfReader
from collections import Counter
import pandas as pd
import math

# %%
# Download NLTK resources
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/new/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def process_pdf(pdf_path, password=None):
  """
  Extracts text from a PDF and performs basic cleaning.

  Args:
    pdf_path (str): Path to the PDF file.
    password (str, optional): Password for the PDF (if password-protected). Defaults to None.

  Returns:
    str: Cleaned text extracted from the PDF, or None if there's an issue.
  """

  # Check if PDF path exists
  if not os.path.exists(pdf_path):
    print(f"Error: PDF file not found: {pdf_path}")
    return None

  text = ""
  try:
    with open(pdf_path, 'rb') as f:
      reader = PdfReader(f, password=password)  # Provide password if needed
      for page in reader.pages:
        text += page.extract_text()

    # Basic validation on extracted text
    if not text:
      print(f"Warning: Empty text extracted from PDF: {pdf_path}")
      return None

  except (IOError, PdfReaderError) as e:
    print(f"Error processing PDF {pdf_path}: {e}")
    return None

  # Preprocess text (optional)
  sentences = nltk.sent_tokenize(text)  # Tokenize into sentences
  words = [w.lower() for w in nltk.word_tokenize(text) if w.isalpha()]  # Tokenize, lowercase, filter alphanumeric

  # Remove stop words (optional)
  stop_words = set(stopwords.words('english'))
  words = [w for w in words if w not in stop_words]

  # Join words back into a string
  cleaned_text = " ".join(words)

  return cleaned_text



def process_pdfs(data_dir, password=None):
  """
  Processes all PDFs within a directory structure, recursively searching subfolders.

  Args:
    data_dir (str): Path to the top-level directory containing PDFs.
    password (str, optional): Password for the PDFs (if password-protected). Defaults to None.

  Returns:
    list: List of tuples, where each tuple contains (PDF path, processed text).
  """
  numPDF = 0
  corpus = []
  for root, _, files in os.walk(data_dir):
    for filename in files:
      if filename.endswith(".pdf"):
        pdf_path = os.path.join(root, filename)
        numPDF = numPDF + 1
        print(f"Processing PDF: {pdf_path}")
        print(f"There are this many PDFs:{numPDF}")
        text = process_pdf(pdf_path, password)
        if text:
          corpus.append((pdf_path, text))

  return corpus

# %%
# data_dir path points to top-level directory containing PDFs
data_dir = "files"

# Process PDFs and create corpus
pdf_data = process_pdfs(data_dir)
# Out:
# Processing PDF: files/1450/Demertzis et al_2023_Federated Auto-Meta-Ensemble Learning Framework for AI-Enabled Military.pdf
# There are this many PDFs:1
# Processing PDF: files/1457/Mao et al_2022_Trustworthy AI Solutions for Cyberbiosecurity Challenges in Water Supply Systems.pdf
# There are this many PDFs:2
# Processing PDF: files/1468/Paul_2023_A survey of technologies supporting design of a multimodal interactive robot.pdf
# There are this many PDFs:3
# Processing PDF: files/1461/Xiao et al_2022_Guest Editorial.pdf
# There are this many PDFs:4
# Processing PDF: files/1466/Miljković_Beriša_2023_Application of artificial intelligence in modern warfare.pdf
# There are this many PDFs:5
# Processing PDF: files/1459/Schuett_2022_Three lines of defense against risks from AI.pdf
# There are this many PDFs:6
# Processing PDF: files/1467/Nalin_Tripodi_2023_Future Warfare and Responsibility Management in the AI-based Military.pdf
# There are this many PDFs:7
# Processing PDF: files/1458/Moreno et al_2022_The ethics of AI-assisted warfighter enhancement research and experimentation.pdf
# There are this many PDFs:8
# Processing PDF: files/1460/Wang_Chapman_2022_Risk-averse autonomous systems.pdf
# There are this many PDFs:9
# Processing PDF: files/1456/Lee_Jang_2022_Necessity of establishing an open source military R&D platform to promote AI.pdf
# There are this many PDFs:10
# Processing PDF: files/1469/Rashid et al_2023_Artificial Intelligence in the Military.pdf
# There are this many PDFs:11
# Processing PDF: files/1451/Johnson_2023_Automating the OODA loop in the age of intelligent machines.pdf
# There are this many PDFs:12
# Processing PDF: files/1523/Taddeo and Blanchard - 2022 - A Comparative Analysis of the Definitions of Auton.pdf
# There are this many PDFs:13
# Processing PDF: files/1343/Rivera et al. - 2024 - Escalation Risks from Language Models in Military .pdf
# There are this many PDFs:14
# Processing PDF: files/1513/Longpre et al. - 2022 - Lethal autonomous weapons systems & artificialinte.pdf
# There are this many PDFs:15
# Processing PDF: files/1335/Chrvalová - 2022 - LETHAL AUTONOMOUS WEAPONS SYSTEMS.pdf
# There are this many PDFs:16
# Processing PDF: files/1508/Androschuk - 2023 - The level of trust in artificial intelligence an .pdf
# There are this many PDFs:17
# Processing PDF: files/1530/Falletti and Gallese - 2022 - Ethical and Legal Limits to the Diffusion of Self-.pdf
# There are this many PDFs:18
# Processing PDF: files/1506/Kahn - 2022 - Lethal autonomous weapon systems and respect for h.pdf
# There are this many PDFs:19
# Processing PDF: files/1501/Taddeo and Blanchard - 2022 - Accepting Moral Responsibility for the Actions of .pdf
# There are this many PDFs:20
# Processing PDF: files/1487/Fazelnia et al. - 2022 - Attacks, Defenses, And Tools A Framework To Facil.pdf
# There are this many PDFs:21
# Processing PDF: files/1473/Seyed jalal Dehghani Firozabadi_Saeed Chehrazad_2023_Artificial Intelligence and Problematization of National Security Topics.pdf
# There are this many PDFs:22
# Processing PDF: files/1474/Shimaa S. Mohamed et al_2023_Neutrosophic MCDM Methodology for Risk Assessment of Autonomous Underwater.pdf
# There are this many PDFs:23
# Processing PDF: files/1480/Gunneflo and Noll - 2023 - Technologies of Decision Support and Proportionali.pdf
# There are this many PDFs:24
# Processing PDF: files/1488/Blauth et al. - 2022 - Artificial Intelligence Crime An Overview of Mali.pdf
# There are this many PDFs:25
# Processing PDF: files/1481/Al-Hussaini et al. - 2022 - Seeking Human Help to Manage Plan Failure Risks in.pdf
# There are this many PDFs:26
# Processing PDF: files/1475/ŞİMŞEK_KİRİSCİ_2023_A NEW RISK ASSESSMENT METHOD FOR AUTONOMOUS VEHICLE DRIVING SYSTEMS.pdf
# There are this many PDFs:27
# Processing PDF: files/1472/Sebastian_2023_Do ChatGPT and Other AI Chatbots Pose a Cybersecurity Risk.pdf
# There are this many PDFs:28
# Processing PDF: files/1486/Bächle and Bareis - 2022 - “Autonomous weapons” as a geopolitical signifier i.pdf
# There are this many PDFs:29
# Processing PDF: files/1454/Johnson_2022_Delegating strategic decision-making to machines.pdf
# There are this many PDFs:30
# Processing PDF: files/1453/Sun et al_2023_CANARY.pdf
# There are this many PDFs:31
# Processing PDF: files/1465/Lekea et al_2023_Exploring Enhanced Military Ethics and Legal Compliance through Automated.pdf
# There are this many PDFs:32
# Processing PDF: files/1496/Veluwenkamp - 2022 - Reasons for Meaningful Human Control.pdf
# There are this many PDFs:33
# Processing PDF: files/1462/BOTEZATU_2023_AI-Centric secure outer space operations.pdf
# There are this many PDFs:34
# Processing PDF: files/1463/Harshith et al_2023_Evaluating the Vulnerabilities in ML systems in terms of adversarial attacks.pdf
# There are this many PDFs:35
# Processing PDF: files/1464/Kereopa-Yorke_2023_ClausewitzGPT_Framework.pdf
# There are this many PDFs:36
# Processing PDF: files/1464/.ipynb_checkpoints/Kereopa-Yorke_2023_ClausewitzGPT_Framework-checkpoint.pdf
# There are this many PDFs:37
# Processing PDF: files/1452/Oimann_2023_The Responsibility Gap and LAWS.pdf
# There are this many PDFs:38
# Processing PDF: files/1455/Jorge Peña Queralta et al_2022_Secure Encoded Instruction Graphs for End-to-End Data Validation in Autonomous.pdf
# There are this many PDFs:39
# Processing PDF: files/1439/Meerveld et al. - 2023 - The irresponsibility of not using AI in the milita.pdf
# There are this many PDFs:40
# Processing PDF: files/1527/Roden-Bow - 2023 - Killer Robots and Inauthenticity A Heideggerian R.pdf
# There are this many PDFs:41
# Processing PDF: files/1516/Syse and Cook - 2023 - Robotic Virtue, Military Ethics Education, and the.pdf
# There are this many PDFs:42
# Processing PDF: files/1511/Umbrello - 2022 - Editorial for the Special Issue on Meaningful Huma.pdf
# There are this many PDFs:43
# Processing PDF: files/1510/Hoffmann and Frase - 2023 - Adding Structure to AI Harm.pdf
# There are this many PDFs:44
# Processing PDF: files/1528/Blanchard and Taddeo - 2022 - Jus in bello Necessity, The Requirement of .pdf
# There are this many PDFs:45
# Processing PDF: files/1738/Pan and Mishra - 2023 - AI Trojan Attack for Evading Machine Learning-base.pdf
# There are this many PDFs:46
# Processing PDF: files/1737/Dorton and Harper - 2022 - A Naturalistic Investigation of Trust, AI, and Int.pdf
# There are this many PDFs:47
# Processing PDF: files/1448/Tóth et al_2022_The Dawn of the AI Robots.pdf
# There are this many PDFs:48
# Processing PDF: files/1477/Hunter and Bowen - 2023 - We’ll never have a model of an AI major-general A.pdf
# There are this many PDFs:49
# Processing PDF: files/1483/Goldfarb and Lindsay - 2022 - Prediction and Judgment Why Artificial Intelligen.pdf
# There are this many PDFs:50
# Processing PDF: files/1484/Maathuis - 2022 - On Explainable AI Solutions for Targeting in Cyber.pdf
# There are this many PDFs:51
# Processing PDF: files/1470/Sangwan et al_2023_Cybersecurity for AI Systems.pdf
# There are this many PDFs:52
# Processing PDF: files/1479/Luo - 2022 - Addressing military AI risks in U.S.–China crisis .pdf
# There are this many PDFs:53
# Processing PDF: files/1446/Hagos_Rawat_2022_Recent Advances in Artificial Intelligence and Tactical Autonomy.pdf
# There are this many PDFs:54
# Processing PDF: files/1478/Bode et al. - 2023 - Prospects for the global governance of autonomous .pdf
# There are this many PDFs:55
# Processing PDF: files/1447/Johnson_2022_The AI Commander Problem.pdf
# There are this many PDFs:56
# Processing PDF: files/1471/Santoso_Finn_2023_An In-Depth Examination of Artificial Intelligence-Enhanced Cybersecurity in.pdf
# There are this many PDFs:57
# Processing PDF: files/1485/Devitt - 2023 - Bad, mad, and cooked Moral responsibility for civ.pdf
# There are this many PDFs:58
# Processing PDF: files/1449/Vyhmeister et al_2022_A responsible AI framework.pdf
# There are this many PDFs:59
# Processing PDF: files/1482/Hamad and Steinhorst - 2023 - Security Challenges in Autonomous Systems Design.pdf
# There are this many PDFs:60
# Processing PDF: files/1476/2023_Autonomous Weapon Systems.pdf
# There are this many PDFs:61

# %%
"""
vectorizer = TfidfVectorizer(max_features=1000)

    This line creates a TfidfVectorizer object from the sklearn.feature_extraction.text library.
    
    TfidfVectorizer is used to convert text data into a numerical representation suitable for machine learning algorithms like TF-IDF.
    
    The max_features parameter (set to 1000 here) specifies the maximum number of features (words) the vectorizer will consider.
    
    This helps control the dimensionality of the resulting TF-IDF matrix.
    
    You can adjust this value based on your specific needs and the size of your corpus.

tfidf_matrix = vectorizer.fit_transform([text for path, text in pdf_data])

    Fit: It calls the fit method on the vectorizer.
    
    This method analyzes the text data provided (the list comprehension) to build the vocabulary. 
    
    The vocabulary is essentially a list of unique words encountered across all your PDFs.
    
    Transform: After fitting, the transform method is called. This method uses the created vocabulary to convert the text data from your pdf_data list into a numerical representation suitable for TF-IDF analysis. 
    
    The output is stored in the tfidf_matrix variable.
"""

vectorizer = TfidfVectorizer(max_features=100)  # Adjust max_features as needed
tfidf_matrix = vectorizer.fit_transform([text for path, text in pdf_data])

# %%
print(type(tfidf_matrix), tfidf_matrix.shape)
# Out:
# <class 'scipy.sparse._csr.csr_matrix'> (61, 100)

# %%
"""
    This list of feature names represents the vocabulary created by the TF-IDF vectorizer for the entire corpus.
"""
feature_names = vectorizer.get_feature_names_out()
print(feature_names)
print(tfidf_matrix)
# Out:
# ['actions' 'adversarial' 'ai' 'al' 'also' 'analysis' 'applications'
#  'approach' 'article' 'artificial' 'attack' 'attacks' 'autonomous'
#  'autonomy' 'aws' 'based' 'challenges' 'conference' 'control' 'could'
#  'data' 'decision' 'decisions' 'defense' 'development' 'different'
#  'environment' 'et' 'ethical' 'ethics' 'even' 'example' 'framework'
#  'future' 'harm' 'however' 'https' 'human' 'humans' 'ieee' 'information'
#  'intelligence' 'international' 'journal' 'law' 'laws' 'learning' 'legal'
#  'lethal' 'level' 'machine' 'make' 'making' 'may' 'methods' 'might'
#  'military' 'model' 'models' 'moral' 'need' 'new' 'nuclear' 'one'
#  'operations' 'point' 'potential' 'pp' 'process' 'research'
#  'responsibility' 'risk' 'risks' 'robot' 'robots' 'security' 'see' 'state'
#  'states' 'strategic' 'system' 'systems' 'technologies' 'technology'
#  'time' 'training' 'two' 'university' 'us' 'use' 'used' 'using' 'vol'
#  'war' 'warfare' 'weapon' 'weapons' 'within' 'work' 'would']
#   (0, 70)	0.008096227640261737
#   (0, 27)	0.0058249070663090475
#   (0, 77)	0.005637455488987768
#   (0, 44)	0.0066563891230709115
#   (0, 12)	0.005637455488987768
#   (0, 22)	0.0058249070663090475
#   (0, 82)	0.01866880667456718
#   (0, 53)	0.02641444479363877
#   (0, 67)	0.1326135211527691
#   (0, 17)	0.0665638912307091
#   (0, 39)	0.0580702180347704
#   (0, 69)	0.024761899708939772
#   (0, 54)	0.04284237541250233
#   (0, 31)	0.011842816088715288
#   (0, 55)	0.005730280012584544
#   (0, 49)	0.005921408044357644
#   (0, 1)	0.01589254607018428
#   (0, 21)	0.06201201037886545
#   (0, 88)	0.011460560025169087
#   (0, 10)	0.021026453526929074
#   (0, 47)	0.01401763568461938
#   (0, 11)	0.0217763317630389
#   (0, 5)	0.1162235570920106
#   (0, 24)	0.005456948180949553
#   (0, 30)	0.016370844542848657
#   :	:
#   (60, 41)	0.01142498012089093
#   (60, 71)	0.03717167651989662
#   (60, 90)	0.027092933819279793
#   (60, 68)	0.011800831694124112
#   (60, 91)	0.028911303959919588
#   (60, 15)	0.00774083823407994
#   (60, 85)	0.004714379908559083
#   (60, 6)	0.0041301862799885125
#   (60, 50)	0.0041301862799885125
#   (60, 35)	0.011061871762445594
#   (60, 94)	0.019506762995522002
#   (60, 66)	0.01966805282354019
#   (60, 2)	0.01142498012089093
#   (60, 63)	0.01966805282354019
#   (60, 42)	0.35224580122859056
#   (60, 81)	0.13923871995438827
#   (60, 40)	0.01199382197425365
#   (60, 87)	0.02284996024178186
#   (60, 83)	0.014989183031003855
#   (60, 8)	0.04338219310253186
#   (60, 36)	0.13115535152128374
#   (60, 64)	0.004559128336160044
#   (60, 56)	0.08519529620241881
#   (60, 32)	0.01966805282354019
#   (60, 46)	0.004198192594992644

# %%
tf_idf_array = tfidf_matrix.toarray()
print(tfidf_array)
# Out:
# [[0.06934346 0.0075204  0.46512884 0.04093931 0.01386869 0.16329141
#   0.85460348 0.09161629 0.10401279 0.02642602]
#  [0.78131857 0.         0.34031035 0.         0.         0.
#   0.         0.         0.52319228 0.        ]
#  [0.06376682 0.23710648 0.26385505 0.0448178  0.62400392 0.48801814
#   0.12071825 0.3610648  0.30317007 0.06075207]
#  [0.69018011 0.         0.49100315 0.         0.         0.
#   0.27438469 0.35071653 0.25881154 0.13150998]
#  [0.63826492 0.02768831 0.         0.32657888 0.07659179 0.66131971
#   0.         0.         0.19147504 0.0729707 ]
#  [0.58149128 0.         0.02037835 0.37487163 0.00802057 0.0094435
#   0.71743927 0.02852969 0.05263377 0.04966893]
#  [0.76567761 0.19215604 0.06431087 0.07471806 0.28475614 0.20116488
#   0.0503139  0.20579478 0.43305659 0.11454614]
#  [0.42744625 0.0189213  0.20390931 0.08583595 0.26170179 0.81140997
#   0.         0.06205936 0.0981359  0.1662194 ]
#  [0.         0.45679112 0.06824166 0.04204506 0.02441705 0.
#   0.26694589 0.53972952 0.6409326  0.10468197]
#  [0.95342658 0.         0.         0.26059647 0.         0.14967657
#   0.         0.0215327  0.0099313  0.01009278]
#  [0.54585192 0.20029548 0.28363245 0.00403838 0.16416599 0.59436897
#   0.0815813  0.3128299  0.28471879 0.12512366]
#  [0.48449781 0.105089   0.30364497 0.07151001 0.5087227  0.42783952
#   0.03210244 0.15592579 0.42392576 0.10001156]
#  [0.09866562 0.58570781 0.00527759 0.2912533  0.44139881 0.06725626
#   0.         0.17943822 0.54524472 0.18305442]
#  [0.11248726 0.03614639 0.08044832 0.02049714 0.10832106 0.83880978
#   0.4527199  0.04657534 0.04296289 0.23418434]
#  [0.08952692 0.63110619 0.02274665 0.46982502 0.27604134 0.12297823
#   0.03954655 0.12131547 0.49658313 0.13504928]
#  [0.02648524 0.66064348 0.01345853 0.31272953 0.20526059 0.18710394
#   0.         0.03364633 0.61452604 0.09462402]
#  [0.59816039 0.         0.03575959 0.79630664 0.03518591 0.
#   0.         0.         0.03298602 0.06704478]
#  [0.12869673 0.60481846 0.41418432 0.08442285 0.45043854 0.02525481
#   0.         0.0871967  0.38205956 0.28609519]
#  [0.02871629 0.21800268 0.02918449 0.06593089 0.88063294 0.05635143
#   0.         0.01945633 0.11665723 0.39214062]
#  [0.39216732 0.29444623 0.03065857 0.37846176 0.34691724 0.16871336
#   0.03997645 0.30658566 0.51612171 0.32333062]
#  [0.15847684 0.02864508 0.26843451 0.10395809 0.         0.
#   0.73503838 0.1610607  0.56951294 0.02516407]
#  [0.6157852  0.13356562 0.14602588 0.68670575 0.04105235 0.24167727
#   0.         0.04172168 0.21167126 0.05866722]
#  [0.         0.74061627 0.27761415 0.01679893 0.29023296 0.04020274
#   0.06787272 0.12145619 0.51216395 0.08132688]
#  [0.23491489 0.06369216 0.21487053 0.46230045 0.29364362 0.71913714
#   0.01556527 0.10743527 0.14314795 0.2126182 ]
#  [0.80940684 0.0577509  0.25435773 0.24626626 0.09052577 0.01880929
#   0.07056664 0.07576613 0.21965302 0.38556992]
#  [0.         0.14190014 0.20389555 0.         0.50592263 0.02054064
#   0.64732192 0.45211622 0.19625854 0.14127695]
#  [0.         0.64261962 0.06691136 0.1511599  0.26335164 0.
#   0.14541224 0.17843028 0.65836384 0.06272524]
#  [0.47944584 0.         0.67208677 0.04880301 0.19839138 0.
#   0.26290508 0.15121952 0.06199587 0.4252767 ]
#  [0.29138178 0.61696765 0.04230465 0.2138964  0.34688307 0.41386934
#   0.01225824 0.08930983 0.42058598 0.10134818]
#  [0.68807315 0.09376655 0.10617519 0.16660302 0.28819818 0.28418678
#   0.00477395 0.0549182  0.53360458 0.16474368]
#  [0.00697104 0.0075602  0.27158013 0.01829153 0.02556048 0.00273592
#   0.95766348 0.01180783 0.0065352  0.08855287]
#  [0.31267668 0.         0.04888841 0.0473332  0.1864034  0.92745161
#   0.         0.         0.00563707 0.05155858]
#  [0.07149037 0.32563588 0.01453119 0.18289618 0.60051907 0.
#   0.         0.62484136 0.30829506 0.09535464]
#  [0.76765611 0.11008718 0.19343114 0.12485189 0.05709839 0.50794662
#   0.         0.1418495  0.24979966 0.04231026]
#  [0.11641816 0.09820005 0.13146254 0.05091222 0.07761211 0.01523022
#   0.85708603 0.15775505 0.436558   0.02464759]
#  [0.92690402 0.05827484 0.06826207 0.22470792 0.17463409 0.09489968
#   0.16021544 0.01365241 0.11334162 0.06399145]
#  [0.92690402 0.05827484 0.06826207 0.22470792 0.17463409 0.09489968
#   0.16021544 0.01365241 0.11334162 0.06399145]
#  [0.13496217 0.46106062 0.03429066 0.39839792 0.3239092  0.19068701
#   0.         0.30861594 0.55670604 0.25073382]
#  [0.00904132 0.31377411 0.90968426 0.00889642 0.03616527 0.
#   0.         0.10107603 0.23732907 0.07752477]
#  [0.61608621 0.14317597 0.15653278 0.07577663 0.17602463 0.68652625
#   0.         0.02236183 0.16501927 0.1991468 ]
#  [0.08565565 0.70600054 0.         0.16856592 0.22270468 0.10085184
#   0.         0.29597751 0.48180185 0.29378172]
#  [0.45251939 0.03635288 0.         0.18140527 0.1508398  0.78933478
#   0.         0.15329915 0.20425749 0.22354643]
#  [0.03818016 0.66251108 0.03880266 0.15027318 0.38180158 0.13486113
#   0.         0.         0.60848217 0.03637508]
#  [0.97027498 0.01147939 0.15777515 0.11109535 0.04233927 0.
#   0.01402683 0.09323077 0.08930733 0.05042195]
#  [0.18229628 0.42236549 0.02526389 0.26906229 0.16572389 0.49756877
#   0.01098073 0.21895369 0.38063824 0.4973498 ]
#  [0.18053335 0.         0.11607718 0.05075434 0.00368435 0.
#   0.9667245  0.00748885 0.02763202 0.12636597]
#  [0.883334   0.01368555 0.17313484 0.22350291 0.27130973 0.03714452
#   0.08361286 0.18595965 0.10647083 0.1082021 ]
#  [0.96152161 0.05472338 0.04843258 0.01655007 0.18221255 0.04290779
#   0.01485939 0.03703668 0.07621214 0.16558572]
#  [0.95491846 0.02681225 0.08165917 0.14595965 0.11125264 0.20376222
#   0.04095284 0.0251259  0.03186851 0.04710793]
#  [0.6565452  0.04206102 0.50114118 0.26713214 0.18560561 0.42728279
#   0.00734214 0.0337848  0.15841903 0.03694967]
#  [0.55161308 0.00997054 0.14949514 0.04523109 0.11032262 0.70359781
#   0.31676182 0.06540413 0.21546887 0.1138657 ]
#  [0.31893471 0.         0.47899913 0.03835621 0.0177186  0.
#   0.75137275 0.19448085 0.25248413 0.03038562]
#  [0.65986041 0.19138897 0.12476633 0.29444352 0.14578311 0.52397363
#   0.         0.09357475 0.3452678  0.04386025]
#  [0.36213372 0.61233553 0.12663676 0.03065207 0.09734777 0.11003354
#   0.06708193 0.18204034 0.64613088 0.01483926]
#  [0.3143233  0.40194285 0.01907153 0.60010729 0.34716305 0.19885298
#   0.00621696 0.05244671 0.40022516 0.23688847]
#  [0.55396075 0.17737272 0.05361836 0.07267776 0.62254637 0.45346145
#   0.01398286 0.06434203 0.17805469 0.15581801]
#  [0.08745345 0.13497109 0.35209886 0.07943257 0.03363594 0.02772231
#   0.12034929 0.58797092 0.69372524 0.022432  ]
#  [0.78027896 0.0739419  0.09623798 0.19008009 0.41286605 0.30772274
#   0.02509741 0.10778653 0.23791329 0.07939107]
#  [0.9367856  0.0081603  0.11088241 0.0037019  0.15801203 0.
#   0.00997119 0.24470601 0.11639009 0.10752969]
#  [0.00695056 0.73118453 0.25429986 0.10258759 0.07645616 0.
#   0.03684308 0.40264144 0.46915195 0.02648781]
#  [0.02727464 0.55215537 0.         0.31310475 0.59095062 0.20338516
#   0.         0.0923978  0.33240202 0.29449846]]

# %%
df_tf_idf = pd.DataFrame(tf_idf_array, columns = feature_names)

df_tf_idf
# Out:
#      actions  adversarial        ai        al      also  analysis  \
# 0   0.000000     0.015893  0.051981  0.006435  0.025574  0.116224
# 1   0.000000     0.000000  0.627556  0.000000  0.000000  0.000000
# 2   0.025316     0.017077  0.031280  0.271052  0.024183  0.059038
# 3   0.000000     0.147290  0.240879  0.119275  0.165913  0.000000
# 4   0.000000     0.000000  0.374949  0.000000  0.014758  0.015242
# ..       ...          ...       ...       ...       ...       ...
# 56  0.005744     0.034875  0.059316  0.014121  0.069590  0.039416
# 57  0.060979     0.000000  0.475125  0.000000  0.034042  0.021096
# 58  0.022989     0.000000  0.649538  0.000000  0.023101  0.068929
# 59  0.040544     0.024615  0.005367  0.039866  0.021125  0.000000
# 60  0.033562     0.000000  0.011425  0.004714  0.033726  0.019352
#
#     applications  approach   article  artificial  ...      used     using  \
# 0       0.045100  0.049917  0.017764    0.000000  ...  0.047546  0.095837
# 1       0.000000  0.000000  0.000000    0.000000  ...  0.000000  0.000000
# 2       0.092078  0.033375  0.002545    0.019039  ...  0.086287  0.118732
# 3       0.130618  0.025702  0.027439    0.029322  ...  0.122403  0.000000
# 4       0.016265  0.000000  0.000000    0.419914  ...  0.000000  0.000000
# ..           ...       ...       ...         ...  ...       ...       ...
# 56      0.061855  0.048684  0.046779    0.000000  ...  0.057965  0.098968
# 57      0.007504  0.012305  0.000000    0.030884  ...  0.046881  0.035019
# 58      0.011316  0.097417  0.011886    0.050807  ...  0.103394  0.022632
# 59      0.017463  0.034361  0.000000    0.019601  ...  0.005455  0.029105
# 60      0.004130  0.000000  0.043382    0.013908  ...  0.027093  0.028911
#
#          vol       war   warfare    weapon   weapons    within      work  \
# 0   0.000000  0.007389  0.019969  0.000000  0.000000  0.000000  0.022185
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.161968  0.000000  0.002861  0.006240  0.011641  0.023287  0.021456
# 3   0.068478  0.000000  0.000000  0.000000  0.000000  0.000000  0.128508
# 4   0.042637  0.063955  0.038411  0.020943  0.000000  0.000000  0.000000
# ..       ...       ...       ...       ...       ...       ...       ...
# 56  0.000000  0.000000  0.008764  0.000000  0.000000  0.029062  0.058421
# 57  0.006557  0.157364  0.035442  0.000000  0.012017  0.098828  0.063985
# 58  0.007416  0.000000  0.000000  0.000000  0.000000  0.111775  0.080717
# 59  0.007629  0.000000  0.000000  0.007495  0.000000  0.093237  0.005727
# 60  0.016240  0.054132  0.019507  0.196767  0.262917  0.004410  0.008127
#
#        would
# 0   0.022185
# 1   0.000000
# 2   0.026223
# 3   0.000000
# 4   0.000000
# ..       ...
# 56  0.000000
# 57  0.036914
# 58  0.061233
# 59  0.005727
# 60  0.052825
#
# [61 rows x 100 columns]

# %%
#keywords = ["autonomy"]

# %%
"""keyword_scores = {}
for keyword in keywords:
  # Check if keyword exists in feature_names before accessing the index
  if keyword in feature_names:
    keyword_scores[keyword] = tfidf_matrix.sum(axis=0)[feature_names.tolist().index(keyword)]
  else:
    # Assign 0 score if the keyword is not found
    keyword_scores[keyword] = 0


pdf_scores = {}
for i, (pdf_path, _) in enumerate(pdf_data):
  # Iterate through keyword scores and accumulate for each PDF
  pdf_scores[pdf_path] = 0
  for keyword, score in keyword_scores.items():
    pdf_scores[pdf_path] += score

# Print or analyze PDF scores based on keyword importance
print(pdf_scores)  # This will print a dictionary with scores for each PDF"""
# Out:
# 'keyword_scores = {}\nfor keyword in keywords:\n  # Check if keyword exists in feature_names before accessing the index\n  if keyword in feature_names:\n    keyword_scores[keyword] = tfidf_matrix.sum(axis=0)[feature_names.tolist().index(keyword)]\n  else:\n    # Assign 0 score if the keyword is not found\n    keyword_scores[keyword] = 0\n\n\npdf_scores = {}\nfor i, (pdf_path, _) in enumerate(pdf_data):\n  # Iterate through keyword scores and accumulate for each PDF\n  pdf_scores[pdf_path] = 0\n  for keyword, score in keyword_scores.items():\n    pdf_scores[pdf_path] += score\n\n# Print or analyze PDF scores based on keyword importance\nprint(pdf_scores)  # This will print a dictionary with scores for each PDF'

# %%
# Calculate term frequency (TF) for each word in the corpus
term_frequency = {}
for path, text in pdf_data:
  for word in text.split():
    term_frequency[word] = term_frequency.get(word, 0) + 1

# %%
print(term_frequency)
# Out:
# {'citation': 43, 'demertzis': 8, 'kikiras': 5, 'p': 281, 'skianis': 3, 'rantos': 3, 'iliadis': 8, 'stamoulis': 3, 'federated': 74, 'learning': 930, 'framework': 553, 'military': 1823, 'operations': 406, 'electronics': 47, 'https': 1457, 'academic': 52, 'editors': 14, 'konstantinos': 3, 'limniotis': 1, 'nicholas': 8, 'kolokotronis': 1, 'stavros': 1, 'shiaeles': 1, 'received': 77, 'november': 105, 'revised': 10, 'january': 57, 'accepted': 84, 'published': 92, 'copyright': 30, 'authors': 191, 'licensee': 5, 'mdpi': 14, 'basel': 7, 'switzerland': 19, 'article': 387, 'open': 232, 'access': 269, 'distributed': 151, 'terms': 256, 'conditions': 212, 'creative': 91, 'commons': 80, 'attribution': 68, 'cc': 47, 'license': 89, 'panayotis': 1, 'charalabos': 1, 'lazaros': 1, 'george': 29, 'science': 279, 'technology': 665, 'informatics': 23, 'studies': 293, 'hellenic': 6, 'university': 530, 'patra': 1, 'greece': 16, 'electrical': 25, 'computer': 251, 'engineering': 202, 'thessaly': 1, 'volos': 1, 'department': 183, 'information': 983, 'communication': 282, 'systems': 2685, 'aegean': 1, 'samos': 1, 'international': 1153, 'kavala': 1, 'civil': 56, 'school': 34, 'democritus': 1, 'thrace': 1, 'xanthi': 1, 'correspondence': 14, 'abstract': 59, 'one': 679, 'promises': 7, 'ai': 4094, 'domain': 192, 'seems': 56, 'guarantee': 28, 'adoption': 42, 'broad': 63, 'applicability': 21, 'context': 311, 'potential': 517, 'present': 155, 'operational': 165, 'domains': 93, 'land': 26, 'sea': 35, 'air': 108, 'space': 252, 'levels': 145, 'warfare': 410, 'political': 269, 'strategic': 583, 'tactical': 254, 'however': 492, 'despite': 92, 'convergence': 24, 'needs': 113, 'technological': 213, 'advances': 69, 'still': 180, 'optimal': 95, 'especially': 163, 'supervised': 29, 'machine': 614, 'applications': 398, 'training': 456, 'models': 769, 'requires': 151, 'large': 173, 'amount': 61, 'data': 1564, 'often': 221, 'unavailable': 5, 'difﬁcult': 18, 'produce': 87, 'organization': 76, 'excellent': 5, 'way': 310, 'tackle': 15, 'challenge': 110, 'designing': 57, 'pipeline': 44, 'collaboratively': 7, 'mechanism': 45, 'based': 634, 'implementing': 52, 'single': 75, 'universal': 26, 'model': 1356, 'users': 200, 'trained': 95, 'using': 679, 'decentralized': 9, 'furthermore': 92, 'ensures': 27, 'privacy': 140, 'protection': 82, 'sensitive': 39, 'managed': 13, 'entity': 48, 'process': 567, 'raises': 42, 'severe': 41, 'objections': 4, 'effectiveness': 142, 'generalizability': 2, 'usually': 46, 'algorithm': 250, 'shows': 101, 'sensitivity': 50, 'managing': 35, 'available': 298, 'revealing': 14, 'complex': 267, 'relationships': 48, 'characterize': 18, 'forecast': 8, 'biases': 49, 'paper': 263, 'proposes': 9, 'holistic': 12, 'approach': 464, 'address': 118, 'problem': 299, 'famel': 12, 'user': 247, 'federation': 24, 'automatically': 25, 'creates': 35, 'appropriate': 129, 'hyperparameters': 17, 'apply': 79, 'possession': 7, 'federal': 34, 'used': 678, 'create': 120, 'ensemble': 40, 'hence': 69, 'highly': 99, 'accurate': 46, 'without': 339, 'exposing': 4, 'personal': 88, 'turns': 10, 'experimentally': 2, 'offers': 55, 'better': 205, 'predictability': 59, 'stability': 160, 'overall': 78, 'behavior': 164, 'smoothens': 3, 'noise': 68, 'reducing': 52, 'risk': 929, 'wrong': 50, 'choice': 63, 'resulting': 62, 'keywords': 45, 'cyber': 326, 'defense': 621, 'introduction': 138, 'increasing': 103, 'pace': 20, 'artiﬁcial': 108, 'intelligence': 1096, 'becoming': 51, 'signiﬁcant': 37, 'integral': 10, 'part': 220, 'modern': 139, 'new': 728, 'opportunities': 63, 'complete': 62, 'automation': 227, 'infrastructure': 62, 'optimization': 89, 'numerous': 46, 'defence': 161, 'time': 536, 'complexity': 98, 'growing': 61, 'exponentially': 4, 'number': 235, 'interconnected': 9, 'involved': 113, 'continuous': 35, 'interconnection': 2, 'uninterrupted': 1, 'exchange': 16, 'services': 63, 'expands': 4, 'generalized': 11, 'point': 361, 'view': 140, 'said': 29, 'impact': 229, 'following': 202, 'missions': 42, 'fa ...

# %%
# Calculate Inverse Document Frequency (IDF) for each word
document_frequency = len(pdf_data)
inverse_document_frequency = {}
for word, count in term_frequency.items():
  inverse_document_frequency[word] = math.log(document_frequency / sum(1 for path, text in pdf_data if word in text))

# %%
print(inverse_document_frequency)
# Out:
# {'citation': 1.4718165345580525, 'demertzis': 4.110873864173311, 'kikiras': 4.110873864173311, 'p': 0.0, 'skianis': 4.110873864173311, 'rantos': 4.110873864173311, 'iliadis': 4.110873864173311, 'stamoulis': 4.110873864173311, 'federated': 2.501435951739211, 'learning': 0.17904823144898546, 'framework': 0.10354067894084036, 'military': 0.26072626246325264, 'operations': 0.28223246768421617, 'electronics': 1.5459245067117746, 'https': 0.050430853626891904, 'academic': 0.7786693539981072, 'editors': 1.6259672143853108, 'konstantinos': 4.110873864173311, 'limniotis': 4.110873864173311, 'nicholas': 2.3191143949452564, 'kolokotronis': 4.110873864173311, 'stavros': 4.110873864173311, 'shiaeles': 4.110873864173311, 'received': 0.4219944100593749, 'november': 0.8150369981689821, 'revised': 1.9136492868370918, 'january': 0.9753796482441615, 'accepted': 0.5273549257172012, 'published': 0.44731221804366483, 'copyright': 0.8527773261518292, 'authors': 0.44731221804366483, 'licensee': 2.501435951739211, 'mdpi': 2.3191143949452564, 'basel': 1.4718165345580525, 'switzerland': 1.7129785913749407, 'article': 0.15963014559188393, 'open': 0.21905356606268467, 'access': 0.17904823144898546, 'distributed': 0.676886659688165, 'terms': 0.19885085874516517, 'conditions': 0.26072626246325264, 'creative': 0.5273549257172012, 'commons': 0.614366302706831, 'attribution': 0.8150369981689821, 'cc': 0.0, 'license': 0.5845133395571499, 'panayotis': 4.110873864173311, 'charalabos': 4.110873864173311, 'lazaros': 4.110873864173311, 'george': 1.2776605201170952, 'science': 0.1405819506211894, 'technology': 0.03333642026759171, 'informatics': 1.8082887711792655, 'studies': 0.28223246768421617, 'hellenic': 3.417726683613366, 'university': 0.050430853626891904, 'patra': 4.110873864173311, 'greece': 2.031432322493475, 'electrical': 1.9136492868370918, 'computer': 0.26072626246325264, 'engineering': 0.34967374847974886, 'thessaly': 4.110873864173311, 'volos': 4.110873864173311, 'department': 0.4219944100593749, 'information': 0.12188981760903679, 'communication': 0.5273549257172012, 'systems': 0.0, 'aegean': 4.110873864173311, 'samos': 4.110873864173311, 'international': 0.050430853626891904, 'kavala': 4.110873864173311, 'civil': 0.4219944100593749, 'school': 1.0663514264498881, 'democritus': 4.110873864173311, 'thrace': 4.110873864173311, 'xanthi': 4.110873864173311, 'correspondence': 1.4718165345580525, 'abstract': 0.23967285326542026, 'one': 0.016529301951210506, 'promises': 1.9136492868370918, 'ai': 0.0, 'domain': 0.34967374847974886, 'seems': 0.9753796482441615, 'guarantee': 0.9328200338253656, 'adoption': 0.9328200338253656, 'broad': 0.21905356606268467, 'applicability': 1.33828514193353, 'context': 0.21905356606268467, 'potential': 0.06782259633876109, 'present': 0.03333642026759171, 'operational': 0.30421137440299156, 'domains': 0.614366302706831, 'land': 0.23967285326542026, 'sea': 0.016529301951210506, 'air': 0.08552217343816193, 'space': 0.4219944100593749, 'levels': 0.5273549257172012, 'warfare': 0.3732042458899429, 'political': 0.5845133395571499, 'strategic': 0.5845133395571499, 'tactical': 1.0663514264498881, 'however': 0.03333642026759171, 'despite': 0.49995595152908684, 'convergence': 1.5459245067117746, 'needs': 0.32668423025505017, 'technological': 0.5273549257172012, 'advances': 0.5845133395571499, 'still': 0.23967285326542026, 'optimal': 1.33828514193353, 'especially': 0.30421137440299156, 'supervised': 1.6259672143853108, 'machine': 0.12188981760903679, 'applications': 0.15963014559188393, 'training': 0.30421137440299156, 'models': 0.39730179746900346, 'requires': 0.28223246768421617, 'large': 0.21905356606268467, 'amount': 0.32668423025505017, 'data': 0.050430853626891904, 'often': 0.19885085874516517, 'unavailable': 2.501435951739211, 'difﬁcult': 2.501435951739211, 'produce': 0.34967374847974886, 'organization': 0.49995595152908684, 'excellent': 2.501435951739211, 'way': 0.1405819506211894, 'tackle': 1.4718165345580525, 'challenge': 0.179048231 ...

# %%
# Calculate TF-IDF score for each word in the corpus
tf_idf = {}
for path, text in pdf_data:
  words = text.split()
  for word in words:
    tf_idf[(path, word)] = term_frequency[word] * inverse_document_frequency[word]

# %%
# Identify most unique PDFs based on TF-IDF scores
unique_pdfs = []
for path, text in pdf_data:
  # Calculate average TF-IDF score for each PDF
  pdf_score = sum(score for word, score in tf_idf.items() if word in text.split()) / len(text.split())
  unique_pdfs.append((path, pdf_score))

# %%
# Sort PDFs by their scores in descending order (most unique first)
unique_pdfs.sort(key=lambda x: x[1], reverse=True)

# %%
# Print names of the top N most unique PDFs (adjust N as desired)
num_unique_to_print = 10
for i in range(min(num_unique_to_print, len(unique_pdfs))):
  path, score = unique_pdfs[i]
  print(f"Unique PDF: {path} (TF-IDF Score: {score:.2f})")
# Out:
# Unique PDF: files/1450/Demertzis et al_2023_Federated Auto-Meta-Ensemble Learning Framework for AI-Enabled Military.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1457/Mao et al_2022_Trustworthy AI Solutions for Cyberbiosecurity Challenges in Water Supply Systems.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1468/Paul_2023_A survey of technologies supporting design of a multimodal interactive robot.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1461/Xiao et al_2022_Guest Editorial.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1466/Miljković_Beriša_2023_Application of artificial intelligence in modern warfare.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1459/Schuett_2022_Three lines of defense against risks from AI.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1467/Nalin_Tripodi_2023_Future Warfare and Responsibility Management in the AI-based Military.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1458/Moreno et al_2022_The ethics of AI-assisted warfighter enhancement research and experimentation.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1460/Wang_Chapman_2022_Risk-averse autonomous systems.pdf (TF-IDF Score: 0.00)
# Unique PDF: files/1456/Lee_Jang_2022_Necessity of establishing an open source military R&D platform to promote AI.pdf (TF-IDF Score: 0.00)
